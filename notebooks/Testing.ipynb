# %%
import pandas as pd

df = pd.read_csv("../data/raw/nifty50.csv")

df.head(), df.tail(), df.shape
# Out:
# (        Price             Close             High               Low  \
#  0      Ticker             ^NSEI            ^NSEI             ^NSEI
#  1        Date               NaN              NaN               NaN
#  2  2007-09-17  4494.64990234375  4549.0498046875  4482.85009765625
#  3  2007-09-18   4546.2001953125  4551.7998046875   4481.5498046875
#  4  2007-09-19  4732.35009765625           4739.0           4550.25
#
#                 Open Volume
#  0             ^NSEI  ^NSEI
#  1               NaN    NaN
#  2   4518.4501953125      0
#  3  4494.10009765625      0
#  4           4550.25      0  ,
#             Price            Close             High              Low  \
#  4506  2026-01-28         25342.75  25372.099609375  25187.650390625
#  4507  2026-01-29  25418.900390625  25458.150390625   25159.80078125
#  4508  2026-01-30  25320.650390625   25370.69921875  25213.650390625
#  4509  2026-02-02  25088.400390625  25108.099609375  24679.400390625
# ...
